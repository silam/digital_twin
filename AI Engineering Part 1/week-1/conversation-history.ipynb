# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display
from pprint import pprint

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
if OPENAI_API_KEY is None:
    raise Exception("API Key is missing!")
else:
    print("Key is: " + OPENAI_API_KEY[:8])

client = OpenAI()

messages = []

messages = [
                {"role": "system", "content":"You are a helpful assistant!"},
        {"role": "user", "content":"Next week I am going to travel to Spain."}
    ]

response = client.chat.completions.create(
    model = "gpt-4.1-mini",
    messages= messages
)

reply = response.choices[0].message.content
pprint(reply)
# Out:
# Key is: sk-proj-
# ('That sounds exciting! Do you need any tips or information about traveling to '
#  'Spain?')

# %%
messages.append({"role": "assistant", "content" : reply})
messages.append({"role": "user", "content":"Where do I travel next week"})

##pprint(messages)
response = client.chat.completions.create(
    model = "gpt-4.1-mini",
    messages= messages
)

reply = response.choices[0].message.content
pprint(reply)
# Out:
# ('You mentioned that you are traveling to Spain next week. If you have any '
#  'other travel plans or need assistance with a different destination, please '
#  'let me know!')

# %%
messages.append({"role": "assistant", "content" : reply})
messages.append({"role": "user", "content":"What is capital?"})

##pprint(messages)
response = client.chat.completions.create(
    model = "gpt-4.1-mini",
    messages= messages
)

reply = response.choices[0].message.content
pprint(reply)
# Out:
# ("The capital of Spain is Madrid. It's a vibrant city known for its art, "
#  "culture, and historic sites. If you're visiting Spain, Madrid is definitely "
#  'worth exploring!')
