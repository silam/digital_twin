# %% [markdown]
# ### Step 1: Import Libraries and load the env variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
if OPENAI_API_KEY is None:
    raise Exception("API Key is missing!")
else:
    print("Key is: " + OPENAI_API_KEY[:8])
# Out:
# Key is: sk-proj-

# %%
client = OpenAI()

response = client.chat.completions.create(
    model = "gpt-4.1-mini",
    messages= [
        {"role": "user", "content":"What is OCAPI"}
    ]
)

answer = response.choices[0].message.content

print(answer)
# Out:
# OCAPI stands for **Open Commerce API**. It is an API framework provided by Salesforce Commerce Cloud (formerly Demandware) that allows developers to interact programmatically with the platform's various commerce functionalities.
#
# ### Key Points about OCAPI:
# - **Purpose:** Enables integration and customization of Salesforce Commerce Cloud capabilities, such as product catalogs, customer data, orders, and more.
# - **Types of OCAPI:**
#   - **Shop API:** Used mainly on the storefront side to access catalog data, customer info, and to place orders.
#   - **Data API:** Used on the administrative side to manage data like products, inventory, customer profiles, and orders.
#   - **Meta API:** Used to query metadata about the object models like definitions of custom objects.
# - **Usage:** OCAPI is typically accessed via RESTful web services, allowing external applications or storefront customizations to perform operations like searching for products, retrieving customer info, managing carts, etc.
# - **Authentication:** Provides various authentication mechanisms including OAuth, client credentials, and session-based tokens depending on the context.
# - **Customization:** Developers can configure and extend OCAPI endpoints in Commerce Cloud to suit specific business requirements.
#
# In summary, OCAPI is a core interface mechanism in Salesforce Commerce Cloud for enabling extensive programmatic access to e-commerce functionalities.
